# %% [markdown]
# # This project based on covid-19 database in the world

# %%
# I tried to make this data easy to understand in the end, this data will be presented in the form of a chart

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('worldometer_data.csv')
data
# Out:
#        Country/Region          Continent    Population  TotalCases  NewCases  \
# 0                 USA      North America  3.310023e+08     2727996     143.0
# 1              Brazil      South America  2.125582e+08     1408485       NaN
# 2              Russia             Europe  1.459346e+08      647849       NaN
# 3               India               Asia  1.379975e+09      585792       NaN
# 4                  UK             Europe  6.788605e+07      312654       NaN
# ..                ...                ...           ...         ...       ...
# 204      Vatican City             Europe  8.010000e+02          12       NaN
# 205        Montserrat      North America  4.992000e+03          11       NaN
# 206  Papua New Guinea  Australia/Oceania  8.945849e+06          11       NaN
# 207    Western Sahara             Africa  5.971930e+05          10       NaN
# 208        MS Zaandam                NaN           NaN           9       NaN
#
# ...

# %%
new_data = data[['Continent','Country/Region', 'TotalCases', 'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical']]
new_data
# Out:
#              Continent    Country/Region  TotalCases  TotalDeaths  \
# 0        North America               USA     2727996     130123.0
# 1        South America            Brazil     1408485      59656.0
# 2               Europe            Russia      647849       9320.0
# 3                 Asia             India      585792      17410.0
# 4               Europe                UK      312654      43730.0
# ..                 ...               ...         ...          ...
# 204             Europe      Vatican City          12          NaN
# 205      North America        Montserrat          11          1.0
# 206  Australia/Oceania  Papua New Guinea          11          NaN
# 207             Africa    Western Sahara          10          1.0
# 208                NaN        MS Zaandam           9          2.0
#
#      TotalRecovered  ActiveCases  Serious,Critical
# 0         1143490.0    1454383.0           15935.0
# 1          790040.0     558789.0            8318.0
# ...

# %%
filt1 = new_data['TotalCases'] > 50000
data_filt = new_data[filt1]
data_filt
# Out:
#         Continent Country/Region  TotalCases  TotalDeaths  TotalRecovered  \
# 0   North America            USA     2727996     130123.0       1143490.0
# 1   South America         Brazil     1408485      59656.0        790040.0
# 2          Europe         Russia      647849       9320.0        412650.0
# 3            Asia          India      585792      17410.0        347979.0
# 4          Europe             UK      312654      43730.0             NaN
# 5          Europe          Spain      296351      28355.0             NaN
# 6   South America           Peru      285213       9677.0        174535.0
# 7   South America          Chile      279393       5688.0        241229.0
# 8          Europe          Italy      240578      34767.0        190248.0
# 9            Asia           Iran      227662      10817.0        188758.0
# 10  North America         Mexico      226089      27769.0        134957.0
# 11           Asia       Pakistan      213470       4395.0        100802.0
# ...

# %%
filt1 = new_data['TotalCases'] > 50000
filt2 = new_data['Continent'] == 'Asia'
filt = filt1 & filt2
new_data[filt]
# Out:
#    Continent Country/Region  TotalCases  TotalDeaths  TotalRecovered  \
# 3       Asia          India      585792      17410.0        347979.0
# 9       Asia           Iran      227662      10817.0        188758.0
# 11      Asia       Pakistan      213470       4395.0        100802.0
# 12      Asia         Turkey      199906       5131.0        173111.0
# 14      Asia   Saudi Arabia      190823       1649.0        130766.0
# 17      Asia     Bangladesh      145483       1847.0         59624.0
# 20      Asia          Qatar       96088        113.0         81564.0
# 27      Asia      Indonesia       56385       2876.0         24806.0
#
#     ActiveCases  Serious,Critical
# 3      220403.0            8944.0
# 9       28087.0            3049.0
# 11     108273.0            2741.0
# 12      21664.0            1026.0
# 14      58408.0            2278.0
# 17      84012.0               1.0
# 20      14411.0             200.0
# 27      28703.0               NaN

# %%
data_filt.head()
# Out:
#        Continent Country/Region  TotalCases  TotalDeaths  TotalRecovered  \
# 0  North America            USA     2727996     130123.0       1143490.0
# 1  South America         Brazil     1408485      59656.0        790040.0
# 2         Europe         Russia      647849       9320.0        412650.0
# 3           Asia          India      585792      17410.0        347979.0
# 4         Europe             UK      312654      43730.0             NaN
#
#    ActiveCases  Serious,Critical
# 0    1454383.0           15935.0
# 1     558789.0            8318.0
# 2     225879.0            2300.0
# 3     220403.0            8944.0
# 4          NaN             276.0

# %%
df_replace = data_filt.fillna(0)
df_replace
# Out:
#         Continent Country/Region  TotalCases  TotalDeaths  TotalRecovered  \
# 0   North America            USA     2727996     130123.0       1143490.0
# 1   South America         Brazil     1408485      59656.0        790040.0
# 2          Europe         Russia      647849       9320.0        412650.0
# 3            Asia          India      585792      17410.0        347979.0
# 4          Europe             UK      312654      43730.0             0.0
# 5          Europe          Spain      296351      28355.0             0.0
# 6   South America           Peru      285213       9677.0        174535.0
# 7   South America          Chile      279393       5688.0        241229.0
# 8          Europe          Italy      240578      34767.0        190248.0
# 9            Asia           Iran      227662      10817.0        188758.0
# 10  North America         Mexico      226089      27769.0        134957.0
# 11           Asia       Pakistan      213470       4395.0        100802.0
# ...

# %%
filt3 = df_replace['Continent'] == 'Asia'
filt4 = df_replace['Continent'] == 'Europe'
filt = filt3 | filt4
data_clear = df_replace[filt]
data_clear
# Out:
#    Continent Country/Region  TotalCases  TotalDeaths  TotalRecovered  \
# 2     Europe         Russia      647849       9320.0        412650.0
# 3       Asia          India      585792      17410.0        347979.0
# 4     Europe             UK      312654      43730.0             0.0
# 5     Europe          Spain      296351      28355.0             0.0
# 8     Europe          Italy      240578      34767.0        190248.0
# 9       Asia           Iran      227662      10817.0        188758.0
# 11      Asia       Pakistan      213470       4395.0        100802.0
# 12      Asia         Turkey      199906       5131.0        173111.0
# 13    Europe        Germany      195832       9052.0        179800.0
# 14      Asia   Saudi Arabia      190823       1649.0        130766.0
# 15    Europe         France      164801      29843.0         76274.0
# 17      Asia     Bangladesh      145483       1847.0         59624.0
# 20      Asia          Qatar       96088        113.0         81564.0
# ...

# %%
data_sort = data_clear.sort_values('TotalCases', ascending = True)
data_sort
# Out:
#    Continent Country/Region  TotalCases  TotalDeaths  TotalRecovered  \
# 28    Europe    Netherlands       50273       6113.0             0.0
# 27      Asia      Indonesia       56385       2876.0         24806.0
# 25    Europe        Belgium       61427       9747.0         16984.0
# 24    Europe        Belarus       62118        392.0         46054.0
# 21    Europe         Sweden       68451       5333.0             0.0
# 20      Asia          Qatar       96088        113.0         81564.0
# 17      Asia     Bangladesh      145483       1847.0         59624.0
# 15    Europe         France      164801      29843.0         76274.0
# 14      Asia   Saudi Arabia      190823       1649.0        130766.0
# 13    Europe        Germany      195832       9052.0        179800.0
# 12      Asia         Turkey      199906       5131.0        173111.0
# 11      Asia       Pakistan      213470       4395.0        100802.0
# 9       Asia           Iran      227662      10817.0        188758.0
# ...

# %%
ds_clear = data_sort.set_index('Country/Region')
ds_clear
# Out:
#                Continent  TotalCases  TotalDeaths  TotalRecovered  \
# Country/Region
# Netherlands       Europe       50273       6113.0             0.0
# Indonesia           Asia       56385       2876.0         24806.0
# Belgium           Europe       61427       9747.0         16984.0
# Belarus           Europe       62118        392.0         46054.0
# Sweden            Europe       68451       5333.0             0.0
# Qatar               Asia       96088        113.0         81564.0
# Bangladesh          Asia      145483       1847.0         59624.0
# France            Europe      164801      29843.0         76274.0
# Saudi Arabia        Asia      190823       1649.0        130766.0
# Germany           Europe      195832       9052.0        179800.0
# Turkey              Asia      199906       5131.0        173111.0
# Pakistan            Asia      213470       4395.0        100802.0
# Iran                Asia      227662      10817.0        188758.0
# ...

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x = 'TotalCases', y = 'TotalRecovered', data = ds_clear)
graph

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips = [
    ('index', '$index'),
    ('(TotalCases, TotalRecovered)', '(@TotalCases, @TotalRecovered)'),
    ('Continent', '@Continent')
])

plot = figure(title ='Data Covid-19', x_axis_label='TotalCases', y_axis_label='TotalRecovered', plot_width=700, plot_height=700, tools=[TOOLTIPS])
plot.circle('TotalCases','TotalRecovered', size=10, source=ds_clear)
show(plot)

# %%
ds_clear.plot.bar(stacked=True, figsize=(15,6.5))
plt.title('Data Covid-19')
# Out:
# Text(0.5, 1.0, 'Data Covid-19')
